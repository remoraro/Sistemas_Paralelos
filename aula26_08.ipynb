# %% [markdown]
# # Classificação de Pipelines
#
# Um *Pipeline* tem várias classificações, mas por enquanto vamos separar em ***escalares*** e ***vetoriais***
#
# O resto (dinâmica/estático, unifunção/multifunção) foram ideias inovadoras mas não foram adotadas e caíram no esquecimento
